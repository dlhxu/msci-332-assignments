# %%
import random
import numpy as np
import pprint

# %%
def instanceGeneration(T):
        
    #Jeffrey Quiambao's student number -> 20663172
    random.seed(3172)
    
    #instantiate list to hold instances for each period
    instances = []

    for period in range(T):
        #Generate per unit ordering cost ct Uniform[10,20]
        orderingCost = round(random.uniform(10,20),1)

        #Generate per unit holding cost ht Uniform[5,15]
        holdingCost = round(random.uniform(5,15),1)

        #Generate integer demand dt using Uniform[0,20]
        demand = round(random.uniform(0,20))

        #Set storage capacity S = 40
        storageCapacity = 40

        #Assume number of units ordered per week cannot exceed Q = 40
        maxUnitsOrdered = 40
        
        if (period+1 == 1):
            stock = 0
        else:
            stock = "TBD"

        instances.insert(len(instances), {"orderingCost": orderingCost, "holdingCost": holdingCost, "demand":demand, 
               "storageCapacity":storageCapacity, "maxUnitsOrdered":maxUnitsOrdered, "stock": stock})
    
    return(instances)

def getStats(instances):
    orderingCost = []
    holdingCost = []
    demand = []
    storageCapacity = []
    maxUnitsOrdered = []
    #stock = []
    
    #put all generated instances into an array
    for instance in instances:
        orderingCost.insert(len(orderingCost), instance["orderingCost"])
        holdingCost.insert(len(holdingCost), instance["holdingCost"])
        demand.insert(len(demand), instance["demand"])
        storageCapacity.insert(len(storageCapacity), instance["storageCapacity"])
        maxUnitsOrdered.insert(len(maxUnitsOrdered), instance["maxUnitsOrdered"])
    
    return({"periods": len(orderingCost), "orderingCost": orderingCost, "avgOrderingCost": average(orderingCost), "stdOrderingCost": np.std(orderingCost),
          "holdingCost": holdingCost,"avgHoldingCost": average(holdingCost), "stdOrderingCost": np.std(holdingCost),
          "demand": demand, "avgDemand": average(demand), "stdDemand": np.std(demand),
          "maxUnitsOrdered": average(maxUnitsOrdered), "storageCapacity": average(storageCapacity)})

def average(lst):
    return sum(lst)/len(lst)

#Generate 10 random instances for each value T = 10, 20, 30, T weeks    
tenWeeks = instanceGeneration(10)
twentyWeeks = instanceGeneration(20)
thirtyWeeks = instanceGeneration(30)
tenWeeksStats = getStats(tenWeeks)
twentyWeeksStats = getStats(twentyWeeks)
thirtyWeeksStats = getStats(thirtyWeeks)

pprint.pprint(tenWeeks)
print('\n')
pprint.pprint(tenWeeksStats)
print('\n')
#pprint.pprint(twentyWeeks)
print('\n')
pprint.pprint(twentyWeeksStats)
print('\n')
#pprint.pprint(thirtyWeeks)
print('\n')
pprint.pprint(thirtyWeeksStats)

#Get average and standard deviation over 10 instances
# Out:
# [{'demand': 10,
#   'holdingCost': 14.1,
#   'maxUnitsOrdered': 40,
#   'orderingCost': 17.4,
#   'stock': 0,
#   'storageCapacity': 40},
#  {'demand': 20,
#   'holdingCost': 11.2,
#   'maxUnitsOrdered': 40,
#   'orderingCost': 19.2,
#   'stock': 'TBD',
#   'storageCapacity': 40},
#  {'demand': 13,
#   'holdingCost': 9.2,
#   'maxUnitsOrdered': 40,
#   'orderingCost': 16.4,
#   'stock': 'TBD',
#   'storageCapacity': 40},
#  {'demand': 13,
#   'holdingCost': 14.4,
#   'maxUnitsOrdered': 40,
#   'orderingCost': 10.4,
#   'stock': 'TBD',
#   'storageCapacity': 40},
#  {'demand': 2,
#   'holdingCost': 7.4,
#   'maxUnitsOrdered': 40,
#   'orderingCost': 18.1,
#   'stock': 'TBD',
#   'storageCapacity': 40},
#  {'demand': 14,
#   'holdingCost': 5.1,
#   'maxUnitsOrdered': 40,
#   'orderingCost': 12.3,
#   'stock': 'TBD',
#   'storageCapacity': 40},
#  {'demand': 3,
#   'holdingCost': 10.9,
#   'maxUnitsOrdered': 40,
#   'orderingCost': 14.2,
#   'stock': 'TBD',
#   'storageCapacity': 40},
#  {'demand': 14,
#   'holdingCost': 13.3,
#   'maxUnitsOrdered': 40,
#   'orderingCost': 16.3,
#   'stock': 'TBD',
#   'storageCapacity': 40},
#  {'demand': 17,
#   'holdingCost': 13.1,
#   'maxUnitsOrdered': 40,
#   'orderingCost': 14.0,
#   'stock': 'TBD',
#   'storageCapacity': 40},
#  {'demand': 3,
#   'holdingCost': 8.1,
#   'maxUnitsOrdered': 40,
#   'orderingCost': 11.6,
#   'stock': 'TBD',
#   'storageCapacity': 40}]
#
#
# {'avgDemand': 10.9,
#  'avgHoldingCost': 10.679999999999998,
#  'avgOrderingCost': 14.99,
#  'demand': [10, 20, 13, 13, 2, 14, 3, 14, 17, 3],
#  'holdingCost': [14.1, 11.2, 9.2, 14.4, 7.4, 5.1, 10.9, 13.3, 13.1, 8.1],
#  'maxUnitsOrdered': 40.0,
#  'orderingCost': [17.4, 19.2, 16.4, 10.4, 18.1, 12.3, 14.2, 16.3, 14.0, 11.6],
#  'periods': 10,
#  'stdDemand': 5.940538696111658,
#  'stdOrderingCost': 2.988578257298945,
#  'storageCapacity': 40.0}
#
#
#
#
# {'avgDemand': 9.5,
#  'avgHoldingCost': 10.239999999999998,
#  'avgOrderingCost': 14.930000000000001,
#  'demand': [10,
#             20,
#             13,
#             13,
#             2,
#             14,
#             3,
#             14,
#             17,
#             3,
#             1,
#             1,
#             16,
#             12,
#             3,
#             13,
#             2,
#             4,
#             11,
#             18],
#  'holdingCost': [14.1,
#                  11.2,
#                  9.2,
#                  14.4,
#                  7.4,
#                  5.1,
#                  10.9,
#                  13.3,
#                  13.1,
#                  8.1,
#                  14.4,
#                  10.2,
#                  11.9,
#                  7.1,
#                  7.7,
#                  8.3,
#                  5.9,
#                  10.5,
#                  14.7,
#                  7.3],
#  'maxUnitsOrdered': 40.0,
#  'orderingCost': [17.4,
#                   19.2,
#                   16.4,
#                   10.4,
#                   18.1,
#                   12.3,
#                   14.2,
#                   16.3,
#                   14.0,
#                   11.6,
#                   11.0,
#                   17.9,
#                   15.3,
#                   14.6,
#                   11.7,
#                   11.9,
#                   18.1,
#                   15.1,
#                   16.1,
#                   17.0],
#  'periods': 20,
#  'stdDemand': 6.248999919987197,
#  'stdOrderingCost': 2.990217383402083,
#  'storageCapacity': 40.0}
#
#
#
#
# {'avgDemand': 10.2,
#  'avgHoldingCost': 10.103333333333332,
#  'avgOrderingCost': 15.180000000000001,
#  'demand': [10,
#             20,
#             13,
#             13,
#             2,
#             14,
#             3,
#             14,
#             17,
#             3,
#             1,
#             1,
#             16,
#             12,
#             3,
#             13,
#             2,
#             4,
#             11,
#             18,
#             19,
#             17,
#             5,
#             1,
#             18,
#             11,
#             7,
#             8,
#             14,
#             16],
#  'holdingCost': [14.1,
#                  11.2,
#                  9.2,
#                  14.4,
#                  7.4,
#                  5.1,
#                  10.9,
#                  13.3,
#                  13.1,
#                  8.1,
#                  14.4,
#                  10.2,
#                  11.9,
#                  7.1,
#                  7.7,
#                  8.3,
#                  5.9,
#                  10.5,
#                  14.7,
#                  7.3,
#                  7.6,
#                  9.3,
#                  13.1,
#                  5.6,
#                  13.4,
#                  8.0,
#                  7.6,
#                  13.3,
#                  9.9,
#                  10.5],
#  'maxUnitsOrdered': 40.0,
#  'orderingCost': [17.4,
#                   19.2,
#                   16.4,
#                   10.4,
#                   18.1,
#                   12.3,
#                   14.2,
#                   16.3,
#                   14.0,
#                   11.6,
#                   11.0,
#                   17.9,
#                   15.3,
#                   14.6,
#                   11.7,
#                   11.9,
#                   18.1,
#                   15.1,
#                   16.1,
#                   17.0,
#                   12.4,
#                   17.6,
#                   13.4,
#                   16.0,
#                   18.5,
#                   13.2,
#                   17.9,
#                   18.1,
#                   19.1,
#                   10.6],
#  'periods': 30,
#  'stdDemand': 6.193545026880809,
#  'stdOrderingCost': 2.87140886828903,
#  'storageCapacity': 40.0}

# %%
def shortageCostGeneration(scenario):
    if(scenario == "high"):
        return round(random.uniform(15,35),1)
    elif(scenario == "average"):
        return round(random.uniform(10,25),1)
    elif (scenario == "low"):
        return round(random.uniform(5,15),1)
shortageCostGeneration("high")
# Out:
# 25.2

# %%
pprint.pprint(tenWeeks)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-6168505e1bdd> in <module>
# ----> 1 pprint.pprint(tenWeeks)
#
# NameError: name 'pprint' is not defined
